# %%
import pandas as pd 
import matplotlib.pyplot as plt
import missingno as msno
import matplotlib.pyplot as plt
import re
import json
import os

# %%
#Dataset 1 : players 
df1 = pd.read_excel('wta_2007.xls')
df1.head()
# Out:
#    WTA  Location   Tournament       Date    Tier    Court Surface      Round  \
# 0    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 1    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 2    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 3    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
# 4    1  Auckland  ASB Classic 2007-01-01  Tier 4  Outdoor    Hard  1st Round
#
#    Best of      Winner  ... B365W  B365L   CBW   CBL   EXW   EXL    PSW  \
# 0        3    Sun T.T.  ...  1.33      3  1.38  2.90   NaN   NaN    NaN
# 1        3    Dulko G.  ...  3.75   1.22  4.50  1.18  3.75  1.25  4.700
# 2        3     Loit E.  ...  1.72      2  1.90  1.85  1.80  1.95  1.820
# 3        3  Craybas J.  ...  1.83   1.83  2.15  1.66  2.00  1.75  2.050
# 4        3  Bartoli M.  ...  1.16    4.5  1.16  4.85  1.20  4.25  1.185
#
#      PSL   UBW   UBL
# 0    NaN  1.35  3.05
# 1  1.244  3.75  1.25
# ...
