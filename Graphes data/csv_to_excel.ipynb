# %%
import pandas as pd

# %%
data = pd.read_csv('KaggleMatches_cleaned.csv')
  
data.to_excel('KaggleMatches_cleaned.xlsx', index=False)
# Out:
# C:\Users\sonia\AppData\Local\Temp\ipykernel_33700\3771774781.py:1: DtypeWarning: Columns (3,8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('KaggleMatches_cleaned.csv')
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x0000027976430CD0>>
# Traceback (most recent call last):
#   File "C:\Users\sonia\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('KaggleMatches_cleaned.csv')
df.head()
# Out:
# C:\Users\sonia\AppData\Local\Temp\ipykernel_33700\1304611574.py:1: DtypeWarning: Columns (3,8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('KaggleMatches_cleaned.csv')
#   tourney_id tourney_name surface draw_size tourney_level tourney_date  \
# 0  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 1  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 2  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 3  2019-M020     Brisbane    Hard        32             A   2018-12-31
# 4  2019-M020     Brisbane    Hard        32             A   2018-12-31
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     105453         2.0            0  ...     34.0     20.0
# 1        299     106421         4.0            0  ...     36.0      7.0
# 2        298     105453         2.0            0  ...     15.0      6.0
# ...

# %%
df1 = pd.read_csv('Openchamps_men_nettoye.csv')
df1.head()
# Out:
#    Unnamed: 0  Year       Champion  Seed_Champion Ctry_Champion  \
# 0           0  1969      Rod Laver              1           AUS
# 1           1  1970    Arthur Ashe              4           USA
# 2           2  1971   Ken Rosewall              2           AUS
# 3           3  1972   Ken Rosewall              2           AUS
# 4           4  1973  John Newcombe              2           AUS
#
#           Runner-up  Seed_Runner-up Ctry_Runner-up Score in the Final  \
# 0     Andrés Gimeno               9            ESP      6–3, 6–4, 7–5
# 1       Dick Crealy              12            AUS      6–4, 9–7, 6–2
# 2       Arthur Ashe               3            USA      6–1, 7–5, 6–3
# 3  Malcolm Anderson               8            AUS      7–6, 6–3, 7–5
# 4        Onny Parun              12            NZL      6–3, 6–7, 7–5
#
#    Score1_Champion  Score2_Champion  Score3_Champion  Score1_Runner-up  \
# 0                6                6                7                 3
# ...
