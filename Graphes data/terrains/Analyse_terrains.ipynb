# %% [markdown]
# Ce notebook consiste à faire une analyse sur les terrains de tennis

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# I.Analyse df1 : tennis_courts

# %% [markdown]
# 1.Lecture du dataset

# %%
df1 = pd.read_csv('tennis_courtsV0.csv')
df1.head()
# Out:
#                                      name               address city    state  \
# Northwestern High            Adelphi Road            washington   dc  20782.0
# The Park at Canterbury  Brandywood Circle               orlando   fl  32792.0
# Tippit Middle School       Greenlee Drive     austin-san marcos   tx  78628.0
# Lexington Park               McKee Street  minneapolis-st. paul   mn  55121.0
# Rogers Junior School         Avenue North  minneapolis-st. paul   mn  55374.0
#
#                                     zip_code  type  count   clay   wall  \
# Northwestern High                     Public     6  False   True  False
# The Park at Canterbury  Homeowners Community     1  False  False  False
# Tippit Middle School                  Public     8  False   True  False
# Lexington Park                        Public     1  False  False  False
# Rogers Junior School                  Public     6  False  False  False
#
#                         grass  indoor  lights    proshop   latitude  \
# Northwestern High       False   False   False  38.974351 -76.952112
# The Park at Canterbury  False    True   False  28.590956 -81.285224
# Tippit Middle School    False    True   False  30.615173 -97.700794
# Lexington Park          False   False   False  44.852096 -93.142100
# Rogers Junior School    False   False   False  45.207841 -93.544174
#
#                                                                 longitude
# Northwestern High       {"clay"=>"0", "type"=>"Public", "wall"=>"1", "...
# The Park at Canterbury  {"clay"=>"0", "type"=>"Homeowners Community", ...
# Tippit Middle School    {"clay"=>"0", "type"=>"Public", "wall"=>"1", "...
# Lexington Park          {"clay"=>"0", "type"=>"Public", "wall"=>"0", "...
# Rogers Junior School    {"clay"=>"0", "type"=>"Public", "wall"=>"0", "...

# %%
df1.drop(columns=['clay', 'wall', 'grass', 'indoor', 'lights'], inplace=True)
df1.rename(columns={'clay.1': 'clay', 'wall.1': 'wall', 'grass.1': 'grass', 'indoor.1': 'indoor', 'lights.1': 'lights'}, inplace=True)
df1.head()
# Out:
#                Unnamed: 0               name               address city  \
# 0       Northwestern High       Adelphi Road            washington   dc
# 1  The Park at Canterbury  Brandywood Circle               orlando   fl
# 2    Tippit Middle School     Greenlee Drive     austin-san marcos   tx
# 3          Lexington Park       McKee Street  minneapolis-st. paul   mn
# 4    Rogers Junior School       Avenue North  minneapolis-st. paul   mn
#
#                zip_code  type  count  proshop   latitude  clay  wall  grass  \
# 0                Public     6  False       38 -76.952112     0     1      0
# 1  Homeowners Community     1  False       28 -81.285224     0     0      0
# 2                Public     8  False       30 -97.700794     0     1      0
# 3                Public     1  False       44 -93.142100     0     0      0
# 4                Public     6  False       45 -93.544174     0     0      0
#
#    indoor  lights  stringing
# 0       0       0          0
# 1       0       1          0
# 2       0       1          0
# 3       0       0          0
# 4       0       0          0

# %% [markdown]
# 2.Name / city

# %%
terrain_par_ville = df1.groupby('city')['name'].count()
terrain_par_ville.plot(kind='bar', color='green')
plt.title('Nombre de terrains par ville')
plt.xlabel('Ville')
plt.ylabel('Nombre de terrains')
plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()

# %% [markdown]
# 3.Name / zip_code

# %% [markdown]
# 4.Name /
