# %% [markdown]
# Ce notebook consiste à faire un nettoyage des datasets concernant les terrains de tennis
#
# Source : Open data
#
# Datasets reprèsentant les noms des terrains, les adresses, pays, villes, informations spécifiques aux terrains(surfaces, murs, lumières,...)

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import missingno as msno
import matplotlib.pyplot as plt
import re
import json

# %% [markdown]
# Lecture des datasets

# %%
df1 = pd.read_csv('tennis_courtsV0.csv')
df1.head()
# Out:
#                                      name               address city    state  \
# Northwestern High            Adelphi Road            washington   dc  20782.0
# The Park at Canterbury  Brandywood Circle               orlando   fl  32792.0
# Tippit Middle School       Greenlee Drive     austin-san marcos   tx  78628.0
# Lexington Park               McKee Street  minneapolis-st. paul   mn  55121.0
# Rogers Junior School         Avenue North  minneapolis-st. paul   mn  55374.0
#
#                                     zip_code  type  count   clay   wall  \
# Northwestern High                     Public     6  False   True  False
# The Park at Canterbury  Homeowners Community     1  False  False  False
# Tippit Middle School                  Public     8  False   True  False
# Lexington Park                        Public     1  False  False  False
# Rogers Junior School                  Public     6  False  False  False
#
#                         grass  indoor  lights    proshop   latitude  \
# Northwestern High       False   False   False  38.974351 -76.952112
# The Park at Canterbury  False    True   False  28.590956 -81.285224
# Tippit Middle School    False    True   False  30.615173 -97.700794
# Lexington Park          False   False   False  44.852096 -93.142100
# Rogers Junior School    False   False   False  45.207841 -93.544174
#
#                                                                 longitude
# Northwestern High       {"clay"=>"0", "type"=>"Public", "wall"=>"1", "...
# The Park at Canterbury  {"clay"=>"0", "type"=>"Homeowners Community", ...
# Tippit Middle School    {"clay"=>"0", "type"=>"Public", "wall"=>"1", "...
# Lexington Park          {"clay"=>"0", "type"=>"Public", "wall"=>"0", "...
# Rogers Junior School    {"clay"=>"0", "type"=>"Public", "wall"=>"0", "...

# %%
df2 = pd.read_csv('gps-tennis-courts0.csv')
df2.head()
# Out:
#                 Complex_Na,C,110     Complex_Ty,C,36  \
# 0      Mannibadar Tennis Reserve  Recreation Reserve
# 1      Mannibadar Tennis Reserve  Recreation Reserve
# 2  Cape Clear Recreation Reserve  Recreation Reserve
# 3      Haddon Recreation Reserve  Recreation Reserve
# 4      Haddon Recreation Reserve  Recreation Reserve
#
#                              Facility_N,C,146 Facility_T,C,34  \
# 0     Mannibadar Tennis Reserve Tennis Courts    Tennis Court
# 1     Mannibadar Tennis Reserve Tennis Courts    Tennis Court
# 2  Cape Clear Recreation Reserve Tennis Court    Tennis Court
# 3     Haddon Recreation Reserve Tennis Courts    Tennis Court
# 4     Haddon Recreation Reserve Tennis Courts    Tennis Court
#
#                              Bookable_I,C,146  Assessment,C,18  F8,C,1  \
# 0    Mannibadar Tennis Reserve Tennis Court 1         41400036     NaN
# 1    Mannibadar Tennis Reserve Tennis Court 2         41400036     NaN
# 2  Cape Clear Recreation Reserve Tennis Court         91000683     NaN
# 3    Haddon Recreation Reserve Tennis Court 1         66116405     NaN
# 4    Haddon Recreation Reserve Tennis Court 2         66116405     NaN
#
#    Number,N,19,11         Road_Name,C,88 Locality,C,34  ...  Home_Clubs,C,254  \
# 0            1459  Rokewood-Skipton Road    Mannibadar  ...               NaN
# 1            1459  Rokewood-Skipton Road    Mannibadar  ...               NaN
# 2               0        Recreation Road    Cape Clear  ...               NaN
# 3             396         Sago Hill Road        Haddon  ...               NaN
# 4             396         Sago Hill Road        Haddon  ...               NaN
#
#   Hours_of_O,C,30                                   Descriptio,C,254  \
# 0             NaN  Number of courts: 2\nSurface: Asphalt\nPublic ...
# 1             NaN  Number of courts: 2\nSurface: Asphalt\nPublic ...
# 2             NaN  Number of courts: 1\nSurface: Asphalt\nPublic ...
# 3             NaN  Number of courts: 4\nSurface: Asphalt\nPublic ...
# 4             NaN  Number of courts: 4\nSurface: Asphalt\nPublic ...
#
#   Amenities,C,254 Hire_Agree,C,254  Availabili,C,70 Facebook_P,C,80  \
# 0             NaN              NaN              NaN             NaN
# 1             NaN              NaN              NaN             NaN
# 2             NaN              NaN              NaN             NaN
# 3             NaN              NaN              NaN             NaN
# 4             NaN              NaN              NaN             NaN
#
#    Capacity,C,246  LAT,N,19,11  LONG,N,19,11
# 0             NaN   -37.760717    143.497898
# 1             NaN   -37.760717    143.497898
# 2             NaN   -37.791818    143.611632
# 3             NaN   -37.588120    143.722213
# 4             NaN   -37.588120    143.722213
#
# [5 rows x 24 columns]

# %% [markdown]
# Analyse des datasets

# %% [markdown]
# 1.Suppression des colonnes complétement vides

# %%
def verifier_colonnes_vides(dataframes):
    for i, df in enumerate(dataframes, start=1):
        colonnes_vides = df.columns[df.isnull().all()].tolist()
        if colonnes_vides:
            print(f"Il y a des colonnes vides dans df{i}: {colonnes_vides}")
        else:
            print(f"Aucune colonne vide dans df{i}")
verifier_colonnes_vides([df1, df2])
# Out:
# Aucune colonne vide dans df1
# Il y a des colonnes vides dans df2: ['F8,C,1', 'Hours_of_O,C,30', 'Amenities,C,254', 'Hire_Agree,C,254', 'Availabili,C,70', 'Facebook_P,C,80', 'Capacity,C,246']

# %% [markdown]
# Assurer que les colonnes sont supprimées

# %%
def supprimer_colonnes_vides(dataframes):
    for i, df in enumerate(dataframes, start=1):
        colonnes_vides = df.columns[df.isnull().all()].tolist()
        if colonnes_vides:
            df.drop(columns=colonnes_vides, inplace=True)
            print(f"Colonnes vides supprimées de df{i}: {colonnes_vides}")
        else:
            print(f"Aucune colonne vide dans df{i}")
supprimer_colonnes_vides([df1, df2])
# Out:
# Aucune colonne vide dans df1
# Colonnes vides supprimées de df2: ['F8,C,1', 'Hours_of_O,C,30', 'Amenities,C,254', 'Hire_Agree,C,254', 'Availabili,C,70', 'Facebook_P,C,80', 'Capacity,C,246']

# %%
def profil_donnees(nom_data):
    msno.matrix(nom_data)
    noms_colonnes = nom_data.columns   
    plt.title("Matrice des valeurs manquantes et les noms de colonnes")
    plt.xlabel("Colonnes")
    plt.ylabel("Lignes")
    plt.xticks(ticks=range(len(noms_colonnes)), labels=noms_colonnes, rotation=90)
    plt.show()
profil_donnees(df1)
profil_donnees(df2)

# %% [markdown]
# ----------------------------------------------------  Nettoyage chaque dataset à part ---------------------------------------------------------------------------

# %% [markdown]
# Df1 = tennis_courts

# %% [markdown]
# name: Le nom du lieu où se trouve le terrain de tennis.
#
# address: L'adresse du lieu où se trouve le terrain de tennis.
#
# city: La ville où se trouve le terrain de tennis.
#
# zip_code: Le code postal de la ville où se trouve le terrain de tennis.
#
# type: Le type de terrain de tennis (par exemple, public, communauté de propriétaires, etc.).
#
# count: Le nombre de courts de tennis disponibles à ce lieu.
#
# clay: Un indicateur booléen indiquant si le terrain de tennis est en terre battue (True) ou non (False).
#
# wall: Un indicateur booléen indiquant si le terrain de tennis a un mur de pratique (True) ou non (False).
#
# grass: Un indicateur booléen indiquant si le terrain de tennis est en gazon (True) ou non (False).
#
# indoor: Un indicateur booléen indiquant si le terrain de tennis est couvert (True) ou non (False).
#
# lights: Un indicateur booléen indiquant si le terrain de tennis est éclairé (True) ou non (False).
#
# proshop: Un indicateur booléen indiquant si le lieu dispose d'un magasin de tennis (True) ou non (False).
#
# latitude: La latitude du lieu où se trouve le terrain de tennis.
#
# longitude: La longitude du lieu où se trouve le terrain de tennis

# %% [markdown]
# 1.Suppression de la colonne state

# %%
df1.drop(columns=['state'], inplace=True)

# %% [markdown]
# 3.Colonnes 'proshop' et longitude'

# %%
df1['proshop'] = df1['proshop'].astype('int')
df1.head()
# Out:
#                                      name               address city  \
# Northwestern High            Adelphi Road            washington   dc
# The Park at Canterbury  Brandywood Circle               orlando   fl
# Tippit Middle School       Greenlee Drive     austin-san marcos   tx
# Lexington Park               McKee Street  minneapolis-st. paul   mn
# Rogers Junior School         Avenue North  minneapolis-st. paul   mn
#
#                                     zip_code  type  count   clay   wall  \
# Northwestern High                     Public     6  False   True  False
# The Park at Canterbury  Homeowners Community     1  False  False  False
# Tippit Middle School                  Public     8  False   True  False
# Lexington Park                        Public     1  False  False  False
# Rogers Junior School                  Public     6  False  False  False
#
#                         grass  indoor  lights  proshop   latitude  \
# Northwestern High       False   False   False       38 -76.952112
# The Park at Canterbury  False    True   False       28 -81.285224
# Tippit Middle School    False    True   False       30 -97.700794
# Lexington Park          False   False   False       44 -93.142100
# Rogers Junior School    False   False   False       45 -93.544174
#
#                                                                 longitude
# Northwestern High       {"clay"=>"0", "type"=>"Public", "wall"=>"1", "...
# The Park at Canterbury  {"clay"=>"0", "type"=>"Homeowners Community", ...
# Tippit Middle School    {"clay"=>"0", "type"=>"Public", "wall"=>"1", "...
# Lexington Park          {"clay"=>"0", "type"=>"Public", "wall"=>"0", "...
# Rogers Junior School    {"clay"=>"0", "type"=>"Public", "wall"=>"0", "...

# %%
def extract_specific_values(row):
    data = row['longitude']
    pattern = r'"(clay|wall|grass|indoor|lights|stringing)"=>"([^"]+)"'
    matches = re.findall(pattern, data)
    values = {key: value for key, value in matches}
    return pd.Series(values)
df_extracted = df1.apply(extract_specific_values, axis=1)
df1 = pd.concat([df1, df_extracted], axis=1)
df1 = df1.drop(columns=['longitude'])
df1
# Out:
#                                                                  name  \
# Northwestern High                                        Adelphi Road
# The Park at Canterbury                              Brandywood Circle
# Tippit Middle School                                   Greenlee Drive
# Lexington Park                                           McKee Street
# Rogers Junior School                                     Avenue North
# ...                                                               ...
# Headington Family Tennis Center - University of...  Chautauqua Avenue
# La Mirage                                            La Mirage Circle
# Meridian Villa Estates                               Avenue Southeast
# Brewer Park                                          Southwest Street
# Robinson, J. Sr. Park                                 Ledwicke Street
#
#                                                                            address  \
# Northwestern High                                                       washington
# The Park at Canterbury                                                     orlando
# Tippit Middle School                                             austin-san marcos
# Lexington Park                                                minneapolis-st. paul
# Rogers Junior School                                          minneapolis-st. paul
# ...                                                                            ...
# Headington Family Tennis Center - University of...                   oklahoma city
# La Mirage                                                              los angeles
# Meridian Villa Estates                                                     seattle
# Brewer Park                                                  miami-fort lauderdale
# Robinson, J. Sr. Park                               houston - galveston - brazoria
#
#                                                    city              zip_code  \
# Northwestern High                                    dc                Public
# The Park at Canterbury                               fl  Homeowners Community
# Tippit Middle School                                 tx                Public
# Lexington Park                                       mn                Public
# Rogers Junior School                                 mn                Public
# ...                                                 ...                   ...
# Headington Family Tennis Center - University of...   ok                Public
# La Mirage                                            ca  Homeowners Community
# Meridian Villa Estates                               wa  Homeowners Community
# Brewer Park                                          fl                Public
# Robinson, J. Sr. Park                                tx                Public
#
#                                                     type  count   clay   wall  \
# Northwestern High                                      6  False   True  False
# The Park at Canterbury                                 1  False  False  False
# Tippit Middle School                                   8  False   True  False
# Lexington Park                                         1  False  False  False
# Rogers Junior School                                   6  False  False  False
# ...                                                  ...    ...    ...    ...
# Headington Family Tennis Center - University of...    12  False  False  False
# La Mirage                                              1  False  False  False
# Meridian Villa Estates                                 1  False  False  False
# Brewer Park                                            2  False   True  False
# Robinson, J. Sr. Park                                  1  False  False  False
#
#                                                     grass indoor lights  \
# Northwestern High                                   False  False  False
# The Park at Canterbury                              False   True  False
# Tippit Middle School                                False   True  False
# Lexington Park                                      False  False  False
# Rogers Junior School                                False  False  False
# ...                                                   ...    ...    ...
# Headington Family Tennis Center - University of...  False   True  False
# La Mirage                                           False   True  False
# Meridian Villa Estates                              False  False  False
# Brewer Park                                         False  False  False
# Robinson, J. Sr. Park                               False   True  False
#
#                                                     proshop    latitude clay  \
# Northwestern High                                        38  -76.952112    0
# The Park at Canterbury                                   28  -81.285224    0
# Tippit Middle School                                     30  -97.700794    0
# Lexington Park                                           44  -93.142100    0
# Rogers Junior School                                     45  -93.544174    0
# ...                                                     ...         ...  ...
# Headington Family Tennis Center - University of...       35  -97.448698    0
# La Mirage                                                33 -117.729685    0
# Meridian Villa Estates                                   47 -122.165791    0
# Brewer Park                                              25  -80.296412    0
# Robinson, J. Sr. Park                                    29  -95.271109    0
#
#                                                    wall grass indoor lights  \
# Northwestern High                                     1     0      0      0
# The Park at Canterbury                                0     0      0      1
# Tippit Middle School                                  1     0      0      1
# Lexington Park                                        0     0      0      0
# Rogers Junior School                                  0     0      0      0
# ...                                                 ...   ...    ...    ...
# Headington Family Tennis Center - University of...    0     0      0      1
# La Mirage                                             0     0      0      1
# Meridian Villa Estates                                0     0      0      0
# Brewer Park                                           1     0      0      0
# Robinson, J. Sr. Park                                 0     0      0      1
#
#                                                    stringing
# Northwestern High                                          0
# The Park at Canterbury                                     0
# Tippit Middle School                                       0
# Lexington Park                                             0
# Rogers Junior School                                       0
# ...                                                      ...
# Headington Family Tennis Center - University of...         0
# La Mirage                                                  0
# Meridian Villa Estates                                     0
# Brewer Park                                                0
# Robinson, J. Sr. Park                                      0
#
# [29959 rows x 19 columns]

# %% [markdown]
# -----------------------------------------------------------------Nettoyage dataset 2 -------------------------------------------------------------------

# %%
df2.head()
# Out:
#                 Complex_Na,C,110     Complex_Ty,C,36  \
# 0      Mannibadar Tennis Reserve  Recreation Reserve
# 1      Mannibadar Tennis Reserve  Recreation Reserve
# 2  Cape Clear Recreation Reserve  Recreation Reserve
# 3      Haddon Recreation Reserve  Recreation Reserve
# 4      Haddon Recreation Reserve  Recreation Reserve
#
#                              Facility_N,C,146 Facility_T,C,34  \
# 0     Mannibadar Tennis Reserve Tennis Courts    Tennis Court
# 1     Mannibadar Tennis Reserve Tennis Courts    Tennis Court
# 2  Cape Clear Recreation Reserve Tennis Court    Tennis Court
# 3     Haddon Recreation Reserve Tennis Courts    Tennis Court
# 4     Haddon Recreation Reserve Tennis Courts    Tennis Court
#
#                              Bookable_I,C,146  Assessment,C,18  \
# 0    Mannibadar Tennis Reserve Tennis Court 1         41400036
# 1    Mannibadar Tennis Reserve Tennis Court 2         41400036
# 2  Cape Clear Recreation Reserve Tennis Court         91000683
# 3    Haddon Recreation Reserve Tennis Court 1         66116405
# 4    Haddon Recreation Reserve Tennis Court 2         66116405
#
#    Number,N,19,11         Road_Name,C,88 Locality,C,34  Post_Code,N,19,11  \
# 0            1459  Rokewood-Skipton Road    Mannibadar               3360
# 1            1459  Rokewood-Skipton Road    Mannibadar               3360
# 2               0        Recreation Road    Cape Clear               3351
# 3             396         Sago Hill Road        Haddon               3351
# 4             396         Sago Hill Road        Haddon               3351
#
#   Contact_Na,C,54 Contact_Nu,C,50                  Contact_Em,C,86  \
# 0      Ken Sharpe    0438 154 193             khsharpe@bigpond.com
# 1      Ken Sharpe    0438 154 193             khsharpe@bigpond.com
# 2      Craig Cook    0400 477 493            vk3cmc@bigpond.com.au
# 3      Peter Luke    0410 524 995  luke.peter.r@edumail.vic.gov.au
# 4      Peter Luke    0410 524 995  luke.peter.r@edumail.vic.gov.au
#
#   Home_Clubs,C,254                                   Descriptio,C,254  \
# 0              NaN  Number of courts: 2\nSurface: Asphalt\nPublic ...
# 1              NaN  Number of courts: 2\nSurface: Asphalt\nPublic ...
# 2              NaN  Number of courts: 1\nSurface: Asphalt\nPublic ...
# 3              NaN  Number of courts: 4\nSurface: Asphalt\nPublic ...
# 4              NaN  Number of courts: 4\nSurface: Asphalt\nPublic ...
#
#    LAT,N,19,11  LONG,N,19,11
# 0   -37.760717    143.497898
# 1   -37.760717    143.497898
# 2   -37.791818    143.611632
# 3   -37.588120    143.722213
# 4   -37.588120    143.722213

# %% [markdown]
# Complex_Na :  nom du complexe.
#
# Complex_Ty : type de complexe, par exemple, s'il s'agit d'un centre sportif, d'une piscine, etc.
#
#
# Locality : localité ou le quartier où se trouve le complexe.
#
# Post_Code : code postal du complexe.
#
# Description :  description du complexe ou des installations disponibles.
#
# LAT : la latitude géographique du complexe.
#
# LONG : la longitude géographique du complexe.

# %% [markdown]
# 1. Supression des colonnes innutiles

# %%
#colonnes à supprimer
colonnes_a_supprimer = ['Complex_Ty,C,36', 'Facility_N,C,146', 'Facility_T,C,34', 'Assessment,C,18', 'Number,N,19,11', 'Road_Name,C,88', 'Contact_Na,C,54', 'Contact_Nu,C,50', 'Contact_Em,C,86', 'Home_Clubs,C,254']
df2.drop(columns=colonnes_a_supprimer, inplace=True)
df2.head()
# Out:
#                 Complex_Na,C,110                            Bookable_I,C,146  \
# 0      Mannibadar Tennis Reserve    Mannibadar Tennis Reserve Tennis Court 1
# 1      Mannibadar Tennis Reserve    Mannibadar Tennis Reserve Tennis Court 2
# 2  Cape Clear Recreation Reserve  Cape Clear Recreation Reserve Tennis Court
# 3      Haddon Recreation Reserve    Haddon Recreation Reserve Tennis Court 1
# 4      Haddon Recreation Reserve    Haddon Recreation Reserve Tennis Court 2
#
#   Locality,C,34  Post_Code,N,19,11  \
# 0    Mannibadar               3360
# 1    Mannibadar               3360
# 2    Cape Clear               3351
# 3        Haddon               3351
# 4        Haddon               3351
#
#                                     Descriptio,C,254  LAT,N,19,11  \
# 0  Number of courts: 2\nSurface: Asphalt\nPublic ...   -37.760717
# 1  Number of courts: 2\nSurface: Asphalt\nPublic ...   -37.760717
# 2  Number of courts: 1\nSurface: Asphalt\nPublic ...   -37.791818
# 3  Number of courts: 4\nSurface: Asphalt\nPublic ...   -37.588120
# 4  Number of courts: 4\nSurface: Asphalt\nPublic ...   -37.588120
#
#    LONG,N,19,11
# 0    143.497898
# 1    143.497898
# 2    143.611632
# 3    143.722213
# 4    143.722213

# %% [markdown]
# 2.Traitement de la colonne 'Descriptio,C,254'

# %%
# Diviser les données de la colonne 'Descriptio' en plusieurs colonnes
df2[['Number_courts', 'Surface', 'Public Access']] = df2['Descriptio,C,254'].str.extract(r'Number of courts: (\d+)\nSurface: ([^\n]+)\nPublic Access:([^\n]+)')

# %%
df2.drop(columns=['Descriptio,C,254'], inplace=True)
df2.head()
# Out:
#                 Complex_Na,C,110                            Bookable_I,C,146  \
# 0      Mannibadar Tennis Reserve    Mannibadar Tennis Reserve Tennis Court 1
# 1      Mannibadar Tennis Reserve    Mannibadar Tennis Reserve Tennis Court 2
# 2  Cape Clear Recreation Reserve  Cape Clear Recreation Reserve Tennis Court
# 3      Haddon Recreation Reserve    Haddon Recreation Reserve Tennis Court 1
# 4      Haddon Recreation Reserve    Haddon Recreation Reserve Tennis Court 2
#
#   Locality,C,34  Post_Code,N,19,11  LAT,N,19,11  LONG,N,19,11 Number_courts  \
# 0    Mannibadar               3360   -37.760717    143.497898             2
# 1    Mannibadar               3360   -37.760717    143.497898             2
# 2    Cape Clear               3351   -37.791818    143.611632             1
# 3        Haddon               3351   -37.588120    143.722213             4
# 4        Haddon               3351   -37.588120    143.722213             4
#
#    Surface Public Access
# 0  Asphalt           Yes
# 1  Asphalt           Yes
# 2  Asphalt           Yes
# 3  Asphalt           Yes
# 4  Asphalt           Yes

# %% [markdown]
# 3.Doublons

# %%
df2_filtered = df2[df2['Bookable_I,C,146'].str.match(r'.*Court\s?1?$|.*Court$')]
df2_filtered
# Out:
#                     Complex_Na,C,110  \
# 0          Mannibadar Tennis Reserve
# 2      Cape Clear Recreation Reserve
# 3          Haddon Recreation Reserve
# 7      Ross Creek Recreation Reserve
# 11      Napoleons Recreation Reserve
# 17      Grenville Recreation Reserve
# 19   Woady Yaloak Recreation Reserve
# 23         Linton Recreation Reserve
# 27   Bannockburn Recreation Precinct
# 33     Lethbridge Recreation Reserve
# 36       Rokewood Recreation Reserve
# 38        Enfield Recreation Reserve
# 39      Corindhap Recreation Reserve
# 41   Barunah Park Recreation Reserve
# 43           Shelford Tennis Reserve
# 46       Teesdale Recreation Reserve
#
#               Surface Public Access
# 0             Asphalt           Yes
# 2             Asphalt           Yes
# 3             Asphalt           Yes
# 7           Plexipave           Yes
# 11          Plexipave           Yes
# 17            Asphalt           Yes
# 19  Asphalt/Plexipave           Yes
# 23  Asphalt/Plexipave           Yes
# 27        Rebound Ace           Yes
# 33  Asphalt/Plexipave           Yes
# 36          Plexipave           Yes
# 38            Asphalt           Yes
# 39            Asphalt           Yes
# 41            Asphalt           Yes
# 43  Plexipave/Asphalt           Yes
# 46                NaN           NaN
# 52            Asphalt           Yes
# 56            Asphalt           Yes
# 62            Asphalt           Yes
# 66          Plexipave            No
# 69          Plexipave            No

# %% [markdown]
# 4.Rennomer les colonnes :

# %%
df2_filtered.rename(columns={
    'Complex_Na,C,110': 'Nom_Complexe',
    'Locality,C,34': 'Localisation',
    'Post_Code,N,19,11': 'Code_Postal',
    'LAT,N,19,11': 'Latitude',
    'LONG,N,19,11': 'Longitude',
    'Number_courts': 'Nombre_Terrains',
    'Public Access': 'Acces_Public'
}, inplace=True)

df2_filtered.head()
# Out:
# C:\Users\sonia\AppData\Local\Temp\ipykernel_20060\3234073504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_filtered.rename(columns={
#                      Nom_Complexe                            Bookable_I,C,146  \
# 0       Mannibadar Tennis Reserve      Mannibadar Tennis Reserve Tennis Court
# 2   Cape Clear Recreation Reserve  Cape Clear Recreation Reserve Tennis Court
# 3       Haddon Recreation Reserve      Haddon Recreation Reserve Tennis Court
# 7   Ross Creek Recreation Reserve  Ross Creek Recreation Reserve Tennis Court
# 11   Napoleons Recreation Reserve   Napoleons Recreation Reserve Tennis Court
#
#    Localisation  Code_Postal   Latitude   Longitude Nombre_Terrains  \
# 0    Mannibadar         3360 -37.760717  143.497898               2
# 2    Cape Clear         3351 -37.791818  143.611632               1
# 3        Haddon         3351 -37.588120  143.722213               4
# 7    Ross Creek         3351 -37.632091  143.758713               4
# 11    Napoleons         3352 -37.680147  143.825216               6
#
#       Surface Acces_Public
# 0     Asphalt          Yes
# 2     Asphalt          Yes
# 3     Asphalt          Yes
# 7   Plexipave          Yes
# 11  Plexipave          Yes

# %%
df2_filtered.drop(columns=['Bookable_I,C,146'], inplace=True)
df2_filtered.head()
# Out:
# C:\Users\sonia\AppData\Local\Temp\ipykernel_20060\2749166705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_filtered.drop(columns=['Bookable_I,C,146'], inplace=True)
#                      Nom_Complexe Localisation  Code_Postal   Latitude  \
# 0       Mannibadar Tennis Reserve   Mannibadar         3360 -37.760717
# 2   Cape Clear Recreation Reserve   Cape Clear         3351 -37.791818
# 3       Haddon Recreation Reserve       Haddon         3351 -37.588120
# 7   Ross Creek Recreation Reserve   Ross Creek         3351 -37.632091
# 11   Napoleons Recreation Reserve    Napoleons         3352 -37.680147
#
#      Longitude Nombre_Terrains    Surface Acces_Public
# 0   143.497898               2    Asphalt          Yes
# 2   143.611632               1    Asphalt          Yes
# 3   143.722213               4    Asphalt          Yes
# 7   143.758713               4  Plexipave          Yes
# 11  143.825216               6  Plexipave          Yes

# %% [markdown]
# Sauvegarde des df1 et df2

# %%
df1.to_csv('tennis_court_nettoye.csv')

# %%
df2_filtered.to_csv('gps-tennis-courts_nettoye.csv')
